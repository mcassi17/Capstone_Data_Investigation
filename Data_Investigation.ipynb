# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime 
# %matplotlib inline
import seaborn as sb

# %%
bikeshare = pd.read_csv('bikeshare_reduced.csv', 
                        parse_dates=['Start date', 'End date', 'start_date_short', 'end_date_short'])

# %%
bikeshare.shape
# Out:
# (1405380, 18)

# %%
bikeshare.head()
# Out:
#    Unnamed: 0          Start date            End date  \
# 0           0 2011-06-30 23:59:00 2011-07-01 00:09:00
# 1           1 2011-06-30 23:58:00 2011-07-01 00:03:00
# 2           2 2011-06-30 23:59:00 2011-07-01 00:09:00
# 3           3 2011-06-30 23:58:00 2011-07-01 00:17:00
# 4           4 2011-06-30 23:58:00 2011-07-01 00:28:00
#
#                                   Start station  \
# 0                   11th & Kenyon St NW (31102)
# 1               Lamont & Mt Pleasant NW (31107)
# 2  Massachusetts Ave & Dupont Circle NW (31200)
# 3         4th St & Massachusetts Ave NW (31604)
# 4         10th St & Constitution Ave NW (31219)
#
#                                        End station Member Type  \
# 0               Calvert St & Woodley Pl NW (31106)  Registered
# 1              Adams Mill & Columbia Rd NW (31104)  Registered
# 2              Adams Mill & Columbia Rd NW (31104)      Casual
# 3           C & O Canal & Wisconsin Ave NW (31225)  Registered
# 4  14th & D St NW / Ronald Reagan Building (31231)      Casual
#
#   start_date_short end_date_short  time_diff  season  mnth  holiday  weekday  \
# 0       2011-06-30     2011-07-01       10.0       3     6        0        4
# 1       2011-06-30     2011-07-01        5.0       3     6        0        4
# 2       2011-06-30     2011-07-01       10.0       3     6        0        4
# 3       2011-06-30     2011-07-01       19.0       3     6        0        4
# 4       2011-06-30     2011-07-01       30.0       3     6        0        4
#
#    workingday  weathersit      temp     atemp       hum  windspeed
# 0           1           1  0.696667  0.637008  0.434167   0.185312
# 1           1           1  0.696667  0.637008  0.434167   0.185312
# 2           1           1  0.696667  0.637008  0.434167   0.185312
# 3           1           1  0.696667  0.637008  0.434167   0.185312
# 4           1           1  0.696667  0.637008  0.434167   0.185312

# %%
bikeshare.tail()
# Out:
#          Unnamed: 0          Start date            End date  \
# 1405375      364218 2012-03-31 23:53:00 2012-04-01 00:03:00
# 1405376      364219 2012-03-31 23:53:00 2012-04-01 00:04:00
# 1405377      364220 2012-03-31 23:54:00 2012-04-01 00:05:00
# 1405378      364221 2012-03-31 23:56:00 2012-03-31 23:59:00
# 1405379      364222 2012-03-31 23:59:00 2012-04-01 00:01:00
#
#              Start station                End station Member Type  \
# 1405375     18th & Bell St          23rd & Crystal Dr      Casual
# 1405376     18th & Bell St          23rd & Crystal Dr      Casual
# 1405377   5th St & K St NW  1st & Rhode Island Ave NW  Registered
# 1405378      3rd & D St SE              1st & K St SE  Registered
# 1405379  23rd & Crystal Dr             18th & Bell St  Registered
#
#         start_date_short end_date_short  time_diff  season  mnth  holiday  \
# 1405375       2012-03-31     2012-04-01       10.0       2     3        0
# 1405376       2012-03-31     2012-04-01       11.0       2     3        0
# 1405377       2012-03-31     2012-04-01       11.0       2     3        0
# 1405378       2012-03-31     2012-03-31        3.0       2     3        0
# 1405379       2012-03-31     2012-04-01        2.0       2     3        0
#
#          weekday  workingday  weathersit      temp     atemp       hum  \
# 1405375        6           0           2  0.424167  0.421708  0.738333
# 1405376        6           0           2  0.424167  0.421708  0.738333
# 1405377        6           0           2  0.424167  0.421708  0.738333
# 1405378        6           0           2  0.424167  0.421708  0.738333
# 1405379        6           0           2  0.424167  0.421708  0.738333
#
#          windspeed
# 1405375   0.250617
# 1405376   0.250617
# 1405377   0.250617
# 1405378   0.250617
# 1405379   0.250617

# %%
bikeshare.drop('Unnamed: 0', 1, inplace=True)

# %%
bikeshare_date_count = bikeshare.groupby('start_date_short')['mnth'].count()
bikeshare_date_count.head(20)
# Out:
# start_date_short
# 2011-04-01    2161
# 2011-04-02    2065
# 2011-04-03    2747
# 2011-04-04    2910
# 2011-04-05    1759
# 2011-04-06    2724
# 2011-04-07    3003
# 2011-04-08    1463
# 2011-04-09    2281
# 2011-04-10    2578
# 2011-04-11    3184
# 2011-04-12    2008
# 2011-04-13    2120
# 2011-04-14    3139
# 2011-04-15    2988
# 2011-04-16     783
# 2011-04-17    3324
# 2011-04-18    3255
# 2011-04-19    3126
# 2011-04-20    3811
# Name: mnth, dtype: int64

# %%
bikeshare_date_count.tail(20)
# Out:
# start_date_short
# 2012-03-12    5121
# 2012-03-13    5700
# 2012-03-14    6139
# 2012-03-15    5998
# 2012-03-16    4314
# 2012-03-17    7147
# 2012-03-18    5460
# 2012-03-19    5970
# 2012-03-20    5904
# 2012-03-21    6048
# 2012-03-22    6626
# 2012-03-23    7773
# 2012-03-24    3248
# 2012-03-25    4747
# 2012-03-26    5424
# 2012-03-27    5013
# 2012-03-28    5562
# 2012-03-29    5971
# 2012-03-30    5339
# 2012-03-31    5782
# Name: mnth, dtype: int64

# %%
bikeshare_date_count.plot()
plt.show()

# %%
bikeshare_time_avg = bikeshare.groupby('start_date_short')['time_diff'].mean()
bikeshare_time_avg.head()
# Out:
# start_date_short
# 2011-04-01    12.341509
# 2011-04-02    17.618402
# 2011-04-03    20.947943
# 2011-04-04    15.874570
# 2011-04-05    11.189881
# Name: time_diff, dtype: float64

# %%
bikeshare_time_avg.tail()
# Out:
# start_date_short
# 2012-03-27    12.030321
# 2012-03-28    12.815894
# 2012-03-29    13.145034
# 2012-03-30    12.690579
# 2012-03-31    17.250432
# Name: time_diff, dtype: float64

# %%
bikeshare_time_avg.plot()
plt.show()

# %%
bikeshare_time_avg_mem = bikeshare.groupby(['start_date_short', 'Member Type'])['time_diff'].mean()
bikeshare_time_avg_mem.head()
# Out:
# start_date_short  Member Type
# 2011-04-01        Casual         24.572549
#                   Registered     10.705142
# 2011-04-02        Casual         28.274373
#                   Registered     11.938382
# 2011-04-03        Casual         31.654701
# Name: time_diff, dtype: float64

# %%
bikeshare['time_diff'].plot.hist(bins=20)
plt.show()

# %%
sb.distplot(bikeshare['time_diff'], bins=25)
plt.xlim([0,85])
plt.show()

# %%
bikeshare.plot.scatter(x='temp', y='time_diff', alpha=0.02)
plt.show()

# %%
sb.lmplot(x='temp', y='time_diff', data=bikeshare, scatter=False)
plt.ylim([0, 20])
plt.show()

# %%
sb.lmplot(x='temp', y='time_diff', hue='Member Type', data=bikeshare, scatter=False)
plt.ylim([0,30])
plt.show()

# %%
bikeshare.plot.scatter(x='windspeed', y='time_diff', alpha=0.02)
plt.show()

# %%
sb.lmplot(x='windspeed', y='time_diff', hue='Member Type', data=bikeshare, scatter=False)
plt.ylim([0,30])
plt.show()

# %%
bikeshare.plot.scatter(x='hum', y='time_diff', alpha=0.02)
plt.show()

# %%
sb.lmplot(x='hum', y='time_diff', data=bikeshare, hue='Member Type', scatter=False)
plt.show()

# %%
member_grouping = bikeshare.groupby('Member Type')['time_diff'].mean()
member_grouping
# Out:
# Member Type
# Casual        25.474315
# Registered    11.636719
# Name: time_diff, dtype: float64

# %%
member_grouping.plot.bar()
plt.show()

# %%
weather_type_grouping = bikeshare.groupby('weathersit')['time_diff'].mean()
weather_type_grouping
# Out:
# weathersit
# 1    14.142818
# 2    13.546364
# 3    10.873936
# Name: time_diff, dtype: float64

# %%
weather_type_grouping.plot.bar()
plt.show()

# %%
workday_grouping = bikeshare.groupby('workingday')['time_diff'].mean()
workday_grouping
# Out:
# workingday
# 0    16.199866
# 1    12.931613
# Name: time_diff, dtype: float64

# %%
workday_grouping.plot.bar()
plt.show()

# %%
weekday_grouping = bikeshare.groupby('weekday')['time_diff'].mean()
weekday_grouping
# Out:
# weekday
# 0    16.111498
# 1    13.569833
# 2    12.817673
# 3    12.663289
# 4    12.821447
# 5    13.194260
# 6    16.413354
# Name: time_diff, dtype: float64

# %%
weekday_grouping.plot.bar()
plt.show()

# %%
holiday_grouping = bikeshare.groupby('holiday')['time_diff'].mean()
holiday_grouping
# Out:
# holiday
# 0    13.861510
# 1    15.442858
# Name: time_diff, dtype: float64

# %%
holiday_grouping.plot.bar()
plt.show()

# %%
season_grouping = bikeshare.groupby('season')['time_diff'].mean()
season_grouping
# Out:
# season
# 1    12.259667
# 2    15.067291
# 3    14.682362
# 4    13.176258
# Name: time_diff, dtype: float64

# %%
season_grouping.plot.bar()
plt.show()

# %%
popular_start = bikeshare.groupby('Start station')['Start station'].count().sort_values(ascending=False)
popular_start.head(20)
# Out:
# Start station
# Massachusetts Ave & Dupont Circle NW (31200)                   42595
# Columbus Circle / Union Station (31623)                        28194
# 15th & P St NW (31201)                                         27997
# Adams Mill & Columbia Rd NW (31104)                            25153
# 17th & Corcoran St NW (31214)                                  24505
# 16th & U St NW (31229)                                         20933
# 14th & V St NW (31101)                                         20848
# 14th & Rhode Island Ave NW (31203)                             20245
# 20th St & Florida Ave NW (31110)                               20154
# 21st & I St NW (31205)                                         19991
# Eastern Market Metro / Pennsylvania Ave & 7th St SE (31613)    19726
# 8th & H St NW (31228)                                          19008
# Calvert St & Woodley Pl NW (31106)                             16878
# 25th St & Pennsylvania Ave NW (31237)                          16612
# USDA / 12th & Independence Ave SW (31217)                      16283
# 5th St & K St NW (31600)                                       16212
# 16th & Harvard St NW (31103)                                   15522
# Park Rd & Holmead Pl NW (31602)                                15198
# 21st & M St NW (31212)                                         14863
# 14th & Harvard St NW (31105)                                   14832
# Name: Start station, dtype: int64

# %%
popular_end = bikeshare.groupby('End station')['End station'].count().sort_values(ascending=False)
popular_end.head(20)
# Out:
# End station
# Massachusetts Ave & Dupont Circle NW (31200)                   46790
# 15th & P St NW (31201)                                         31209
# Columbus Circle / Union Station (31623)                        27965
# 17th & Corcoran St NW (31214)                                  25516
# Adams Mill & Columbia Rd NW (31104)                            22252
# 21st & I St NW (31205)                                         21387
# 14th & V St NW (31101)                                         21161
# 16th & U St NW (31229)                                         20853
# 14th & Rhode Island Ave NW (31203)                             20852
# 8th & H St NW (31228)                                          20772
# 20th St & Florida Ave NW (31110)                               20026
# Eastern Market Metro / Pennsylvania Ave & 7th St SE (31613)    18802
# USDA / 12th & Independence Ave SW (31217)                      18668
# C & O Canal & Wisconsin Ave NW (31225)                         17052
# 25th St & Pennsylvania Ave NW (31237)                          16972
# 5th St & K St NW (31600)                                       16618
# 21st & M St NW (31212)                                         16147
# 18th & M St NW (31221)                                         15657
# Calvert St & Woodley Pl NW (31106)                             15572
# 7th & F St NW / National Portrait Gallery (31232)              15570
# Name: End station, dtype: int64

# %%
bikeshare_points = bikeshare.copy()
bikeshare_points = bikeshare_points[['Start station', 'End station']]
bikeshare_points['Combo'] = bikeshare_points['Start station'] + ' + ' + bikeshare_points['End station']
bikeshare_points.head()
# Out:
#                                   Start station  \
# 0                   11th & Kenyon St NW (31102)
# 1               Lamont & Mt Pleasant NW (31107)
# 2  Massachusetts Ave & Dupont Circle NW (31200)
# 3         4th St & Massachusetts Ave NW (31604)
# 4         10th St & Constitution Ave NW (31219)
#
#                                        End station  \
# 0               Calvert St & Woodley Pl NW (31106)
# 1              Adams Mill & Columbia Rd NW (31104)
# 2              Adams Mill & Columbia Rd NW (31104)
# 3           C & O Canal & Wisconsin Ave NW (31225)
# 4  14th & D St NW / Ronald Reagan Building (31231)
#
#                                                Combo
# 0  11th & Kenyon St NW (31102) + Calvert St & Woo...
# 1  Lamont & Mt Pleasant NW (31107) + Adams Mill &...
# 2  Massachusetts Ave & Dupont Circle NW (31200) +...
# 3  4th St & Massachusetts Ave NW (31604) + C & O ...
# 4  10th St & Constitution Ave NW (31219) + 14th &...

# %%
bikeshare_combo = bikeshare_points.groupby('Combo')['Combo'].count().sort_values(ascending=False)
bikeshare_combo.head(20)
# Out:
# Combo
# Adams Mill & Columbia Rd NW (31104) + Calvert St & Woodley Pl NW (31106)                                           3727
# Eastern Market Metro / Pennsylvania Ave & 7th St SE (31613) + Lincoln Park / 13th & East Capitol St NE  (31619)    3726
# Calvert St & Woodley Pl NW (31106) + Adams Mill & Columbia Rd NW (31104)                                           3690
# Lincoln Park / 13th & East Capitol St NE  (31619) + Eastern Market Metro / Pennsylvania Ave & 7th St SE (31613)    2890
# Massachusetts Ave & Dupont Circle NW (31200) + 15th & P St NW (31201)                                              2704
# 16th & U St NW (31229) + Massachusetts Ave & Dupont Circle NW (31200)                                              2580
# 15th & P St NW (31201) + Massachusetts Ave & Dupont Circle NW (31200)                                              2429
# Columbus Circle / Union Station (31623) + 13th & H St NE (31611)                                                   2390
# Columbus Circle / Union Station (31623) + 13th & D St NE (31622)                                                   2206
# Massachusetts Ave & Dupont Circle NW (31200) + 16th & U St NW (31229)                                              2161
# 13th & D St NE (31622) + Columbus Circle / Union Station (31623)                                                   2055
# 14th & V St NW (31101) + Massachusetts Ave & Dupont Circle NW (31200)                                              2051
# 18th & Bell St (31007) + 27th & Crystal Dr (31009)                                                                 2013
# 13th & H St NE (31611) + Columbus Circle / Union Station (31623)                                                   1935
# 15th & P St NW (31201) + 16th & U St NW (31229)                                                                    1855
# 18th & Bell St (31007) + 23rd & Crystal Dr (31011)                                                                 1832
# Adams Mill & Columbia Rd NW (31104) + Massachusetts Ave & Dupont Circle NW (31200)                                 1750
# 27th & Crystal Dr (31009) + 18th & Bell St (31007)                                                                 1697
# USDA / 12th & Independence Ave SW (31217) + USDA / 12th & Independence Ave SW (31217)                              1685
# Massachusetts Ave & Dupont Circle NW (31200) + 14th & V St NW (31101)                                              1675
# Name: Combo, dtype: int64

# %%
bikeshare_combo.tail(20)
# Out:
# Combo
# 1st & N ST SE + 14th & R St NW                                                                        1
# 1st & N ST SE + 14th & G St NW                                                                        1
# 21st & I St NW (31205) + 23rd & Eads (31013)                                                          1
# Columbia Rd & Georgia Ave NW + C & O Canal & Wisconsin Ave NW                                         1
# 14th & V St NW (31101) + 20th & Bell St (31000)                                                       1
# Georgia Ave and Fairmont St NW + L'Enfant Plaza / 7th & C St SW                                       1
# 7th & Water St SW / SW Waterfront + 7th & T St NW                                                     1
# Van Ness Metro / UDC (31300) + 17th & Rhode Island Ave NW (31239)                                     1
# Van Ness Metro / UDC (31300) + 18th & Bell St (31007)                                                 1
# Georgia Ave and Fairmont St NW + Maryland & Independence Ave SW                                       1
# Potomac & Pennsylvania Ave SE (31606) + 18th St & Pennsylvania Ave NW (31242)                         1
# 14th & V St NW (31101) + 18th & Bell St (31007)                                                       1
# Tenleytown / Wisconsin Ave & Albemarle St NW (31303) + John McCormack Dr & Michigan Ave NE (31502)    1
# 14th & V St NW (31101) + 15th & Hayes St (31005)                                                      1
# 14th & V St NW (31101) + 15th & Crystal Dr (31003)                                                    1
# Georgia Ave and Fairmont St NW + USDA / 12th & Independence Ave SW                                    1
# Georgia Ave and Fairmont St NW + Ward Circle / American University                                    1
# Good Hope & Naylor Rd SE (31700) + 14th & D St SE (31607)                                             1
# Van Ness Metro / UDC (31300) + 23rd & Crystal Dr (31011)                                              1
# 1st & M St NE + Clarendon Blvd & Pierce St                                                            1
# Name: Combo, dtype: int64

# %%
bikeshare_holiday_type = bikeshare.copy()
bikeshare_holiday_type = bikeshare_holiday_type[['Member Type','holiday','time_diff']]
bikeshare_holiday_type_piv = bikeshare_holiday_type.pivot_table(index='Member Type', 
                                                              columns='holiday', aggfunc='mean')
bikeshare_holiday_type_piv
# Out:
#              time_diff
# holiday              0          1
# Member Type
# Casual       25.434672  26.511647
# Registered   11.636263  11.657933

# %%
bikeshare_season_type = bikeshare.copy()
bikeshare_season_type = bikeshare_season_type[['Member Type','season','time_diff']]
bikeshare_season_type_piv = bikeshare_season_type.pivot_table(index='season', 
                                                              columns='Member Type', aggfunc='mean')
bikeshare_season_type_piv
# Out:
#              time_diff
# Member Type     Casual Registered
# season
# 1            25.203856  10.719485
# 2            26.308357  12.376513
# 3            25.234495  12.067951
# 4            24.771671  11.266952

# %%
bikeshare_season_type_piv.plot.bar()
plt.ylim([0,30])
# Out:
# (0, 30)

# %%
bikeshare_weekday_type = bikeshare.copy()
bikeshare_weekday_type = bikeshare_weekday_type[['Member Type','weekday','time_diff']]
bikeshare_weekday_type_piv = bikeshare_weekday_type.pivot_table(index='weekday', 
                                                              columns='Member Type', aggfunc='mean')
bikeshare_weekday_type_piv
# Out:
#              time_diff
# Member Type     Casual Registered
# weekday
# 0            27.160840  11.873056
# 1            25.209396  11.637960
# 2            23.081267  11.552611
# 3            23.146553  11.421584
# 4            23.505895  11.493032
# 5            24.416350  11.442972
# 6            27.283071  12.224354

# %%
bikeshare_weekday_type_piv.plot.bar()

# %%
bikeshare_month_type = bikeshare.copy()
bikeshare_month_type = bikeshare_month_type[['mnth','Member Type','time_diff']]
bikeshare_month_type_piv = bikeshare_month_type.pivot_table(index='mnth', 
                                                              columns='Member Type', aggfunc='mean')
bikeshare_month_type_piv
# Out:
#              time_diff
# Member Type     Casual Registered
# mnth
# 1            23.208684  10.399673
# 2            23.586315  10.446764
# 3            27.144907  11.505566
# 4            27.518608  12.189945
# 5            26.317109  12.831948
# 6            24.700749  12.474875
# 7            25.332177  12.073608
# 8            25.378153  12.086759
# 9            24.703126  11.800379
# 10           25.271762  11.615400
# 11           25.334415  11.191099
# 12           22.911784  10.491094

# %%
bikeshare_month_type_piv.plot.bar()
plt.ylim([0,32])
plt.show()

# %%
bikeshare_work_type = bikeshare.copy()
bikeshare_work_type = bikeshare_work_type[['Member Type','workingday','time_diff']]
bikeshare_work_type_piv = bikeshare_work_type.pivot_table(index='Member Type', 
                                                              columns='workingday', aggfunc='mean')
bikeshare_work_type_piv
# Out:
#              time_diff
# workingday           0          1
# Member Type
# Casual       27.170858  23.781431
# Registered   12.019806  11.504780

# %%
bikeshare_work_type_piv.plot.bar()
plt.show()

# %%
bikeshare['time_diff'].describe()
# Out:
# count    1.405380e+06
# mean     1.389885e+01
# std      1.155961e+01
# min      0.000000e+00
# 25%      7.000000e+00
# 50%      1.100000e+01
# 75%      1.700000e+01
# max      7.900000e+01
# Name: time_diff, dtype: float64

# %%
bikeshare_weather_type = bikeshare.copy()
bikeshare_weather_type = bikeshare_weather_type[['Member Type','weathersit','time_diff']]
bikeshare_weather_type_piv = bikeshare_weather_type.pivot_table(index='weathersit', 
                                                              columns='Member Type', aggfunc='mean')
bikeshare_weather_type_piv.plot.bar()
plt.show()
